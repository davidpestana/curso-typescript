// %% [markdown]
// # 🧪 Módulo 2 — Ejercicios de Tipos de Datos
//
// Practicarás:
// - Tipos especiales
// - Arrays
// - Tuplas
// - Alias
// - Enums
// - Tipos literales
//
// Cada ejercicio tiene:
// - ✏️ Tu celda para resolver
// - ✅ Solución comentada

// %% [markdown]
// ---
// ## 🧩 Ejercicio 1 — Tipos especiales
//
// Declara:
// - `algo`: any
// - `misterio`: unknown
// - una función `nada()` que retorna void
// - una función `fatal()` que retorna never

// %%
// ✏️ Tu solución
// let algo: any = ...
// let misterio: unknown = ...

// function nada(): void { ... }
// function fatal(): never { ... }

// console.log(algo, misterio);

// %% [markdown]
// ### ✅ Solución Ejercicio 1

// %%
let algo: any = "hola";
let misterio: unknown = 123;

function nada(): void {
  console.log("No retorno nada");
}

function fatal(): never {
  throw new Error("Error fatal");
}

console.log("Ej1 →", algo, misterio);
nada();
// Out:
// Ej1 → hola 123
// No retorno nada

// %% [markdown]
// ---
// ## 🧩 Ejercicio 2 — Arrays
//
// Crea:
// - `numeros`: number[]
// - `nombres`: string[]
//
// Y muéstralos en consola.

// %%
// ✏️ Tu solución
// let numeros: number[] = [...];
// let nombres: string[] = [...];
// console.log(numeros, nombres);

// %% [markdown]
// ### ✅ Solución Ejercicio 2

// %%
let numeros: number[] = [1, 2, 3];
let nombres: string[] = ["Ana", "Luis", "Carlos"];

console.log("Ej2 →", numeros, nombres);
// Out:
// Ej2 → [ 1, 2, 3 ] [ "Ana", "Luis", "Carlos" ]

// %% [markdown]
// ---
// ## 🧩 Ejercicio 3 — Tuplas
//
// Crea una tupla:
// - `[string, number]`
//
// Y muéstrala.

// %%
// ✏️ Tu solución
// let producto: [string, number] = [...];
// console.log(producto);

// %% [markdown]
// ### ✅ Solución Ejercicio 3

// %%
let producto: [string, number] = ["Teclado", 39.99];
console.log("Ej3 →", producto);
// Out:
// Ej3 → [ "Teclado", 39.99 ]

// %% [markdown]
// ---
// ## 🧩 Ejercicio 4 — Alias de tipos
//
// Crea:
//
// `type Persona = { nombre: string; edad: number }`
//
// Declara una variable `p` y muéstrala.

// %%
// ✏️ Tu solución
// type Persona = ...
// let p: Persona = ...
// console.log(p);

// %% [markdown]
// ### ✅ Solución Ejercicio 4

// %%
type Persona = { nombre: string; edad: number };
let p: Persona = { nombre: "Juan", edad: 30 };
console.log("Ej4 →", p);
// Out:
// Ej4 → { nombre: "Juan", edad: 30 }

// %% [markdown]
// ---
// ## 🧩 Ejercicio 5 — Enums
//
// Crea:
//
// `enum Estado { Pendiente, Aprobado, Cancelado }`
//
// Declara `estadoActual` y muéstralo.

// %%
// ✏️ Tu solución
// enum Estado { ... }
// let estadoActual: Estado = ...;
// console.log(estadoActual);

// %% [markdown]
// ### ✅ Solución Ejercicio 5

// %%
enum Estado {
  Pendiente = "PENDIENTE",
  Aprobado = "APROBADO",
  Cancelado = "CANCELADO"
}

let estadoActual: Estado = Estado.Aprobado;
console.log("Ej5 →", estadoActual);
// Out:
// Ej5 → APROBADO

// %% [markdown]
// ---
// ## 🧩 Ejercicio 6 — Tipos literales
//
// Define una variable `direccion` que solo acepte:
//
// "Norte" | "Sur" | "Este" | "Oeste"

// %%
// ✏️ Tu solución
// let direccion: "Norte" | "Sur" | "Este" | "Oeste";
// direccion = ...;
// console.log(direccion);

// %% [markdown]
// ### ✅ Solución Ejercicio 6

// %%
let direccion: "Norte" | "Sur" | "Este" | "Oeste";

direccion = "Norte";
console.log("Ej6 →", direccion);

direccion = "Oeste";
console.log("Ej6 →", direccion);
// Out:
// Ej6 → Norte
// Ej6 → Oeste

// %% [markdown]
// ---
// ## 🎉 Fin de los ejercicios del Módulo 2
//
// ➡️ Próximo módulo: **Uniones, intersecciones y narrowing avanzado**.
