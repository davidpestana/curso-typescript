// %% [markdown]
// # 🟦 Módulo 1 — Introducción a TypeScript
//
// Bienvenido al curso **TYP-101 – TypeScript**.
//
// Este primer módulo ofrece una visión general del lenguaje y sienta las bases para todos los módulos posteriores.
//
// No veremos aún POO, módulos, generics o interfaces complejas: este módulo sirve para **acostumbrarse a la sintaxis del lenguaje**, entender el modelo de tipos y empezar a escribir código en TypeScript.
//
// ---
// ## 🎯 Objetivos del módulo
// - Comprender qué es TypeScript y para qué se utiliza.
// - Conocer cómo se integra con JavaScript.
// - Familiarizarse con los tipos básicos del lenguaje.
// - Aprender a definir funciones simples.
// - Practicar operadores fundamentales.
// - Introducir uniones de tipos básicas.
// - Ejecutar TypeScript directamente en notebooks con **Deno**.
//
// ---
// ## 🧠 ¿Qué es TypeScript?
//
// TypeScript es un **superconjunto tipado de JavaScript**, desarrollado por Microsoft.
//
// Esto significa:
// - Todo código JavaScript es válido en TypeScript.
// - Añade un sistema de tipos estático y opcional.
// - Permite detectar errores antes de ejecutar.
// - Mejora el autocompletado y el mantenimiento de código.
//
// ---
// ## 🔌 ¿Cómo se integra TypeScript con JavaScript?
//
// TypeScript se compila a JavaScript utilizando el compilador `tsc`. Cualquier navegador o entorno JavaScript podrá ejecutar el código resultante.
//
// En este curso utilizaremos **Deno** dentro de los notebooks para ejecutar TypeScript sin configuración adicional.
//
// ---
// ## 🚀 Probando nuestro primer TypeScript
// Ejecutemos un simple `console.log`:

// %%
console.log("Hola desde TypeScript en el notebook! ✨");

// %% [markdown]
// ---
// ## 🔤 Tipos básicos en TypeScript
//
// Los tipos más comunes son:
// - `string`
// - `number`
// - `boolean`
// - `null`
// - `undefined`
//
// Ejemplo:

// %%
let nombre: string = "David";
let edad: number = 41;
let activo: boolean = true;

console.log({ nombre, edad, activo });

// %% [markdown]
// ## 📐 Operadores básicos
// ### Operadores aritméticos
// - `+`, `-`, `*`, `/`, `%`
//
// ### Operadores lógicos
// - `&&` (y)
// - `||` (o)
// - `!` (negación)
//
// ### Comparación
// - `===` estricto
// - `!==` estricto
//
// Ejemplo:

// %%
console.log(10 + 5);
console.log(10 === 5);
console.log(true && false);
// Out:
// 15
// false
// false

// %% [markdown]
// ---
// ## ➕ Introducción a funciones en TypeScript
//
// Una función tipada define:
// - el tipo de cada parámetro
// - el tipo de retorno
//
// Ejemplo:

// %%
function saludar(nombre: string, edad: number): string {
  return `Hola ${nombre}, tienes ${edad} años.`;
}

console.log(saludar("Ana", 30));

// %% [markdown]
// ---
// ## 🔀 Uniones de tipos (introducción)
//
// Una variable puede aceptar **más de un tipo**:
//
// ```ts
// let id: number | string;
// ```
//
// Ejemplo:

// %%
let id: number | string = 10;
console.log(id);

id = "ABC123";
console.log(id);

// %% [markdown]
// ---
// ## 📌 Resumen del módulo
// - Comprendiste qué es TS y sus ventajas.
// - Viste cómo se ejecuta TS dentro del notebook.
// - Repasaste los tipos básicos.
// - Aprendiste funciones tipadas.
// - Practicaste operadores fundamentales.
// - Introdujiste uniones simples.
//
// ➡️ En el próximo módulo profundizaremos en **tipos de datos**, como alias, tuplas, enums y arrays avanzados.
