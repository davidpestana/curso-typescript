// %% [markdown]
// # 🧪 Módulo 1 — Ejercicios de Introducción a TypeScript
//
// Estos ejercicios sirven para practicar los conceptos básicos del lenguaje:
//
// - Tipos primitivos
// - Funciones sencillas
// - Operadores
// - Uniones básicas
//
// Cada ejercicio incluye:
// - ✏️ **Celda para tu solución**
// - ✅ **Celda con solución comentada**
//
// ---
// # 🧩 Ejercicio 1 — Declaración de variables
//
// Declara las siguientes variables con su tipo correspondiente:
// - `producto`: string
// - `precio`: number
// - `disponible`: boolean
//
// Y muestra todo en consola.

// %%
// ✏️ Tu solución aquí
// let producto: string = ...
// let precio: number = ...
// let disponible: boolean = ...

// console.log(producto, precio, disponible);

// %% [markdown]
// ### ✅ Solución Ejercicio 1

// %%
let producto: string = "Teclado";
let precio: number = 39.99;
let disponible: boolean = true;

console.log("Ejercicio 1 →", { producto, precio, disponible });
// Out:
// Ejercicio 1 → { producto: "Teclado", precio: 39.99, disponible: true }

// %% [markdown]
// ---
// # 🧩 Ejercicio 2 — Crear una función sencilla
//
// Crea una función `duplicar` que reciba un número y devuelva el doble.
//
// **Requisitos:**
// - Tipar el parámetro
// - Tipar el retorno
// - Llamar a la función dos veces

// %%
// ✏️ Tu solución
// function duplicar(x: number): number {
//   ...
// }

// console.log(duplicar(4));
// console.log(duplicar(9));

// %% [markdown]
// ### ✅ Solución Ejercicio 2

// %%
function duplicar(x: number): number {
  return x * 2;
}

console.log("Ejercicio 2 →", duplicar(4));
console.log("Ejercicio 2 →", duplicar(9));
// Out:
// Ejercicio 2 → 8
// Ejercicio 2 → 18

// %% [markdown]
// ---
// # 🧩 Ejercicio 3 — Operadores
//
// Usa operadores para crear una expresión que resulte en:
//
// 1. La suma de dos números
// 2. Una comparación booleana verdadera
// 3. Una comparación falsa
// 4. Una expresión lógica compleja (&& u ||)
//
// Muestra cada resultado en consola.

// %%
// ✏️ Tu solución
// console.log(...);
// console.log(...);
// console.log(...);
// console.log(...);

// %% [markdown]
// ### ✅ Solución Ejercicio 3

// %%
console.log("Ejercicio 3 →", 5 + 3);
console.log("Ejercicio 3 →", 10 === 10);
console.log("Ejercicio 3 →", 10 === 5);
console.log("Ejercicio 3 →", true && false);
// Out:
// Ejercicio 3 → 8
// Ejercicio 3 → true
// Ejercicio 3 → false
// Ejercicio 3 → false

// %% [markdown]
// ---
// # 🧩 Ejercicio 4 — Uniones de tipos
//
// Crea una variable `codigo` que pueda ser **string o number**.
//
// Asigna primero un número y luego un texto.
//
// Muestra ambas asignaciones en consola.

// %%
// ✏️ Tu solución
// let codigo: number | string = ...
// codigo = ...
// console.log(codigo);
// codigo = ...
// console.log(codigo);

// %% [markdown]
// ### ✅ Solución Ejercicio 4

// %%
let codigo: number | string = 1234;
console.log("Ejercicio 4 →", codigo);

codigo = "ABCD";
console.log("Ejercicio 4 →", codigo);
// Out:
// Ejercicio 4 → 1234
// Ejercicio 4 → ABCD

// %% [markdown]
// ---
// ## 🎉 Fin de los ejercicios del Módulo 1
//
// En este módulo has practicado:
// - Declaración de variables tipadas
// - Funciones básicas
// - Operadores aritméticos, lógicos y comparativos
// - Uniones simples de tipos
//
// ➡️ **Siguiente módulo:** Tipos avanzados, arrays, tuplas, alias y enums.
