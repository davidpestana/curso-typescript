// %% [markdown]
// # 🟪 Módulo 3 — Tipos Avanzados: Uniones, Intersecciones y Narrowing
//
// En este módulo profundizaremos en **técnicas avanzadas de tipado** en TypeScript:
//
// - Tipos unión (`|`)
// - Tipos intersección (`&`)
// - Narrowing (refinamiento de tipos)
// - Narrowing con `typeof`, `in`, `instanceof`
// - Type predicates
// - Discriminated unions
// - Exhaustividad con `never`
//
// Estos conceptos permiten crear modelos más seguros, expresivos y compatibles con aplicaciones reales.
//
// ---

// %% [markdown]
// ## 🔀 1. Tipos Unión
//
// Los tipos unión permiten definir valores que pueden ser **de uno u otro tipo**:
//
// ```ts
// let id: string | number;
// ```
//
// Esto permite más flexibilidad sin perder seguridad.

// %%
let identificador: string | number = "abc123";
console.log(identificador);

identificador = 42;
console.log(identificador);
// Out:
// abc123
// 42

// %% [markdown]
// ## 🧩 2. Tipos Intersección (`&`)
//
// Una intersección combina **dos o más tipos en uno solo**.
//
// Es equivalente a "A y B a la vez":
//
// ```ts
// type A = { a: number }
// type B = { b: string }
// type C = A & B   // tiene a y b
// ```

// %%
type ConNombre = { nombre: string };
type ConEdad = { edad: number };

type Persona = ConNombre & ConEdad;

let persona: Persona = { nombre: "Ana", edad: 30 };
console.log(persona);
// Out:
// { nombre: "Ana", edad: 30 }

// %% [markdown]
// ---
// ## 🕵️ 3. Narrowing (Refinamiento de tipos)
//
// Cuando usamos un tipo unión, TypeScript necesita **saber en tiempo de ejecución** cuál es el tipo actual del valor.
//
// El proceso de ir reduciendo el tipo hasta concretarlo se llama **narrowing**.

// %% [markdown]
// ### 3.1 Narrowing con `typeof`

// %%
function imprimir(valor: string | number) {
  if (typeof valor === "string") {
    console.log("Es un string →", valor.toUpperCase());
  } else {
    console.log("Es un número →", valor * 2);
  }
}

imprimir("hola");
imprimir(10);
// Out:
// Es un string → HOLA
// Es un número → 20

// %% [markdown]
// ### 3.2 Narrowing con `in`
//
// Útil cuando los tipos son objetos que pueden o no tener ciertas propiedades.

// %%
type Admin = { rol: "admin", permisos: string[] };
type Usuario = { rol: "usuario", email: string };

function procesar(persona: Admin | Usuario) {
  if ("permisos" in persona) {
    console.log("Es un admin con permisos →", persona.permisos);
  } else {
    console.log("Es un usuario con email →", persona.email);
  }
}

procesar({ rol: "admin", permisos: ["leer", "escribir"] });
procesar({ rol: "usuario", email: "test@test.com" });
// Out:
// Es un admin con permisos → [ "leer", "escribir" ]
// Es un usuario con email → test@test.com

// %% [markdown]
// ### 3.3 Narrowing con `instanceof`

// %%
class PersonaClase {}
class EmpleadoClase {}

function check(obj: PersonaClase | EmpleadoClase) {
  if (obj instanceof PersonaClase) {
    console.log("Es PersonaClase");
  } else {
    console.log("Es EmpleadoClase");
  }
}

check(new PersonaClase());
check(new EmpleadoClase());
// Out:
// Es PersonaClase
// Es EmpleadoClase

// %% [markdown]
// ### 3.4 Type Predicates (funciones que refinan tipos)
//
// Permiten crear **checks personalizados**:

// %%
function esNumero(x: unknown): x is number {
  return typeof x === "number";
}

let dato: unknown = 55;

if (esNumero(dato)) {
  console.log("Es un número →", dato * 2);
}
// Out:
// Es un número → 110

// %% [markdown]
// ---
// ## 🎭 4. Discriminated Unions
//
// Un patrón esencial para modelar datos complejos.
//
// Cada variante incluye una **propiedad discriminante**:

// %%
type Cuadrado = { tipo: "cuadrado", lado: number };
type Circulo = { tipo: "circulo", radio: number };

type Figura = Cuadrado | Circulo;

function area(fig: Figura) {
  switch (fig.tipo) {
    case "cuadrado":
      return fig.lado * fig.lado;
    case "circulo":
      return Math.PI * fig.radio ** 2;
  }
}

console.log(area({ tipo: "cuadrado", lado: 4 }));
console.log(area({ tipo: "circulo", radio: 3 }));
// Out:
// 16
// 28.274333882308138

// %% [markdown]
// ---
// ## 🧯 5. Exhaustividad con `never`
//
// Es útil para detectar casos no manejados en un `switch`:

// %%
function assertNunca(x: never): never {
  throw new Error("Caso no controlado: " + x);
}

function areaSegura(fig: Figura) {
  switch (fig.tipo) {
    case "cuadrado":
      return fig.lado * fig.lado;
    case "circulo":
      return Math.PI * fig.radio ** 2;
    default:
      assertNunca(fig);
  }
}

console.log(areaSegura({ tipo: "circulo", radio: 4 }));
// Out:
// 50.26548245743669

// %% [markdown]
// ---
// # 🎉 Resumen del Módulo 3
//
// Has aprendido:
//
// - Cómo usar **uniones** para permitir múltiples tipos
// - Cómo usar **intersecciones** para combinar estructuras
// - Cómo aplicar **narrowing** para refinar tipos en tiempo de ejecución
// - Cómo usar **predicados de tipo** para checks personalizados
// - Cómo modelar sistemas reales con **discriminated unions**
// - Cómo usar `never` para asegurar **exhaustividad**
//
// ➡️ Siguiente paso: `modulo03-ejercicios.ipynb`
