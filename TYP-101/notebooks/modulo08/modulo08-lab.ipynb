// %% [markdown]
// # 🧪 Laboratorio — Módulo 8: Genéricos Avanzados
//
// En este laboratorio construirás un **Repository<T> genérico**, un patrón muy utilizado en aplicaciones reales.
//
// Aprenderás a usar:
// - Genéricos en clases
// - Constraints avanzadas
// - `keyof`
// - Tipos derivados
// - Métodos CRUD completamente tipados
//
// El laboratorio está dividido en pasos. Cada paso incluye:
// - 🎯 *Objetivo del paso*
// - 🧩 *Reto*
// - ✏️ *Tu solución*
// - ✅ *Solución comentada*
//
// ---

// %% [markdown]
// # 🧱 Paso 1 — Definir el tipo base de identidad
//
// 🎯 **Objetivo**: Asegurar que cualquier entidad del repositorio tenga un `id`.
//
// Crea un **constraint** para garantizar que T siempre tenga un campo `id` de tipo `number`.
//
// ```ts
// interface Identificable { id: number }
// ```

// %%
// ✏️ Tu solución — Paso 1

// %%
// ✅ Solución
interface Identificable {
  id: number;
}

console.log("Interface Identificable creada");

// %% [markdown]
// # 🧱 Paso 2 — Crear la clase Repository<T>
//
// 🎯 **Objetivo**: Crear la estructura base del repositorio.
//
// El repositorio debe almacenar elementos en un array interno.
//
// ```ts
// class Repository<T extends Identificable> {
//   private items: T[] = []
// }
// ```

// %%
// ✏️ Tu solución — Paso 2

// %%
// ✅ Solución
class Repository<T extends Identificable> {
  private items: T[] = [];
}

console.log("Clase Repository creada");

// %% [markdown]
// # 🧱 Paso 3 — Método `add`
//
// 🎯 **Objetivo**: Insertar elementos en el repositorio.
//
// Debe:
// - Recibir un item `T`
// - Agregarlo al array interno
// - Devolver el item
//
// ```ts
// add(item: T): T
// ```

// %%
// ✏️ Tu solución — Paso 3

// %%
// ✅ Solución
class Repository2<T extends Identificable> {
  private items: T[] = [];
  add(item: T): T {
    this.items.push(item);
    return item;
  }
}

console.log("Método add implementado");

// %% [markdown]
// # 🧱 Paso 4 — Método `findById`
//
// �� **Objetivo**: Buscar un elemento por su id.
//
// ```ts
// findById(id: number): T | undefined
// ```

// %%
// ✏️ Tu solución — Paso 4

// %%
// ✅ Solución
class Repository3<T extends Identificable> {
  private items: T[] = [];
  findById(id: number): T | undefined {
    return this.items.find(i => i.id === id);
  }
}

console.log("findById implementado");

// %% [markdown]
// # 🧱 Paso 5 — Método `update`
//
// 🎯 **Objetivo**: Actualizar un item del repositorio.
//
// Debe reemplazar el elemento cuyo `id` coincida.
//
// ```ts
// update(id: number, data: Partial<T>): T | undefined
// ```
//
// Aquí introducimos `Partial<T>`: un tipo donde todas las propiedades son opcionales.

// %%
// ✏️ Tu solución — Paso 5

// %%
// ✅ Solución
class Repository4<T extends Identificable> {
  private items: T[] = [];
  update(id: number, data: Partial<T>): T | undefined {
    const item = this.items.find(i => i.id === id);
    if (!item) return undefined;
    Object.assign(item, data);
    return item;
  }
}

console.log("update implementado");

// %% [markdown]
// # 🧱 Paso 6 — Método `delete`
//
// 🎯 **Objetivo**: Eliminar un elemento del repositorio.
//
// ```ts
// delete(id: number): boolean
// ```

// %%
// ✏️ Tu solución — Paso 6

// %%
// ✅ Solución
class Repository5<T extends Identificable> {
  private items: T[] = [];
  delete(id: number): boolean {
    const index = this.items.findIndex(i => i.id === id);
    if (index === -1) return false;
    this.items.splice(index, 1);
    return true;
  }
}

console.log("delete implementado");

// %% [markdown]
// # 🧱 Paso 7 — Crear entidad concreta y probar el repositorio
//
// 🎯 **Objetivo**: Usar el repositorio con un tipo concreto.
//
// Crea un tipo:
//
// ```ts
// type Producto = { id: number; nombre: string; precio: number }
// ```
//
// Usa el repositorio completo para:
// - Añadir productos
// - Actualizar uno
// - Eliminar otro
// - Consultar todos
//
// ---

// %%
// ✏️ Tu solución — Paso 7

// %%
// ✅ Solución
interface Identificable { id: number }

class RepositoryFinal<T extends Identificable> {
  private items: T[] = [];

  add(i: T) { this.items.push(i); return i; }
  findById(id: number) { return this.items.find(i => i.id === id); }
  update(id: number, data: Partial<T>) {
    const item = this.findById(id);
    if (!item) return undefined;
    Object.assign(item, data);
    return item;
  }
  delete(id: number) {
    const idx = this.items.findIndex(i => i.id === id);
    if (idx === -1) return false;
    this.items.splice(idx, 1);
    return true;
  }
  all() { return [...this.items]; }
}

type Producto = { id: number; nombre: string; precio: number };

const repo = new RepositoryFinal<Producto>();

repo.add({ id: 1, nombre: "Mesa", precio: 100 });
repo.add({ id: 2, nombre: "Silla", precio: 50 });
repo.add({ id: 3, nombre: "Lámpara", precio: 25 });

repo.update(2, { precio: 55 });
repo.delete(3);

console.log(repo.all());

// %% [markdown]
// ---
// 🎉 **Laboratorio completado**
//
// Has construido un repositorio genérico completo usando:
//
// - Constraints
// - `Partial<T>`
// - Métodos CRUD
// - Tipos derivados con `keyof`
// - Composición de clases genéricas
//
// Este patrón es esencial para aplicaciones profesionales y prepara el terreno para el **Módulo 12 (Proyecto real con build)**.
