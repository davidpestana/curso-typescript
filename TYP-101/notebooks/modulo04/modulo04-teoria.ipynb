// %% [markdown]
// # 🟧 Módulo 4 — Interfaces y Modelado de Objetos
//
// En este módulo aprenderás a utilizar **interfaces** para modelar estructuras de datos y contratos en TypeScript.
//
// Veremos:
// - Qué es una interfaz
// - Propiedades opcionales
// - Propiedades readonly
// - Index signatures
// - Extender interfaces
// - Interfaces vs type alias
// - Implementación de interfaces en objetos y clases
//
// ---

// %% [markdown]
// ## 🧩 1. ¿Qué es una interfaz?
//
// Una **interface** define la forma o estructura que debe tener un objeto.
//
// Ejemplo básico:

// %%
interface Usuario {
  nombre: string;
  edad: number;
}

let u: Usuario = { nombre: "Ana", edad: 30 };
console.log(u);
// Out:
// { nombre: "Ana", edad: 30 }

// %% [markdown]
// ## 🧩 2. Propiedades opcionales (`?`)
//
// Permiten declarar campos que pueden o no estar presentes.
//
// Muy útil para configuraciones o parámetros dinámicos.

// %%
interface Config {
  tema?: string;
  modoOscuro?: boolean;
}

let c1: Config = {};
let c2: Config = { tema: "azul" };

console.log(c1, c2);
// Out:
// {} { tema: "azul" }

// %% [markdown]
// ## 🧩 3. Propiedades readonly
//
// Sirven para impedir que una propiedad sea modificada después de la creación.

// %%
interface Punto {
  readonly x: number;
  readonly y: number;
}

let p: Punto = { x: 10, y: 20 };
// p.x = 15; // ❌ Error

console.log(p);
// Out:
// { x: 10, y: 20 }

// %% [markdown]
// ## 🧩 4. Index Signatures
//
// Permiten declarar estructuras con **claves dinámicas**, como diccionarios:

// %%
interface Diccionario {
  [clave: string]: number;
}

let inventario: Diccionario = {
  manzanas: 10,
  naranjas: 5,
  platanos: 12
};

console.log(inventario);
// Out:
// { manzanas: 10, naranjas: 5, platanos: 12 }

// %% [markdown]
// ## 🧩 5. Extender interfaces (`extends`)
//
// Permite crear estructuras más complejas reutilizando otras.

// %%
interface Persona {
  nombre: string;
}

interface Empleado extends Persona {
  salario: number;
}

let e: Empleado = { nombre: "Luis", salario: 2000 };
console.log(e);
// Out:
// { nombre: "Luis", salario: 2000 }

// %% [markdown]
// ## 🧩 6. Interfaces vs Types
//
// Ambas permiten modelar estructuras.
//
// **Interfaces son mejores cuando:**
// - quieres ser extendido varias veces
// - quieres representar contratos públicos
//
// **Types son mejores cuando:**
// - necesitas uniones o intersecciones
// - necesitas alias para tipos complejos
//
// Ejemplo equivalente:

// %%
interface IUsuario { nombre: string }
type TUsuario = { nombre: string }

let i: IUsuario = { nombre: "Pepe" };
let t: TUsuario = { nombre: "Pepe" };

console.log(i, t);
// Out:
// { nombre: "Pepe" } { nombre: "Pepe" }

// %% [markdown]
// ## 🧩 7. Implementación en Objetos
//
// Los objetos que cumplan la forma exigida pueden declararse como la interfaz.

// %%
interface Producto {
  nombre: string;
  precio: number;
}

let prod: Producto = {
  nombre: "Teclado",
  precio: 49.99
};

console.log(prod);
// Out:
// { nombre: "Teclado", precio: 49.99 }

// %% [markdown]
// ## 🧩 8. Implementación en Clases
//
// Las clases pueden **implementar** interfaces para garantizar estructura.

// %%
interface Animal {
  nombre: string;
  hablar(): string;
}

class Perro implements Animal {
  constructor(public nombre: string) {}
  hablar() { return "Guau"; }
}

let d = new Perro("Toby");
console.log(d.hablar());
// Out:
// Guau

// %% [markdown]
// ## 🧩 9. Múltiples interfaces (implementación múltiple)
//
// Una clase puede implementar varias interfaces a la vez.

// %%
interface ConID { id: number }
interface ConNombre { nombre: string }

class UsuarioSistema implements ConID, ConNombre {
  constructor(public id: number, public nombre: string) {}
}

console.log(new UsuarioSistema(1, "Admin"));
// Out:
// UsuarioSistema { id: 1, nombre: "Admin" }

// %% [markdown]
// ---
// # 🎉 Resumen del Módulo 4
//
// Has aprendido a modelar estructuras complejas usando:
//
// - Interfaces
// - Propiedades opcionales / readonly
// - Index signatures
// - Herencia de interfaces
// - Interfaces vs types
// - Implementación en objetos y clases
//
// Con esto ya estás listo para el **Módulo 5 — Programación Orientada a Objetos en TypeScript**.
